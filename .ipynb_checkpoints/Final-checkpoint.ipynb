# %%
import json
import matplotlib.pyplot as plt
import pandas as pd
import operator
import numpy as np
from matplotlib.font_manager import FontProperties

# %%
file ="data.json"
with open(file, 'r', encoding='utf-8') as obj:
    data = json.load(obj)

# %%
topics=[]
for content in data:
    topics.append(content['topics'])

for i in range(len(topics)):
    a = topics[i]
    
Empty =[]
for i in range(len(topics)):
    a = topics[i]
    catcnt=0
    dogcnt=0
    odogcnt=0
    for j in range(len(a)):
        
        if ((a[j] == "貓咪") or (a[j] == "貓") or (a[j] == "貓貓")):
            catcnt+=1
        elif((a[j] == "狗") or (a[j] == "狗狗")):
            dogcnt+=1
        elif((a[j] == "浪浪") or (a[j] == "野狗") or (a[j] == "流浪狗")):
            odogcnt+=1
        else:
            Empty.append(a[j])
            
    if(catcnt>0):
        Empty.append("貓咪")
    if(dogcnt>0):
        Empty.append("狗")
    if(odogcnt>0):
        Empty.append("浪浪")
#print(Empty)

# %%
WCnt = dict()
for word in Empty:
    if word in WCnt.keys():
        WCnt[word]+=1
    else:
        WCnt[word]=1
    SWC=sorted(WCnt.items(),key=operator.itemgetter(1),reverse=True)

# %%
xf = SWC
Fdf=pd.DataFrame(xf)
Fdf.to_csv('pet_count.csv',encoding='utf-8-sig')
f = open('pet_count.txt','a')
for t in range(0,len(xf)):
    f.writelines(xf[t][0]+","+str(xf[t][1])+"\n")
f.close()
#將結果存進csv檔和txt檔

# %%
acc = pd.read_csv('pet_count.csv')
accData = acc.loc[0:10,['0','1']]
accData = accData.set_index('0')
axes = accData.plot(kind='bar')
myfont = FontProperties(fname=r'./NotoSansCJK-Black.ttc')
for label in axes.get_xticklabels():
    label.set_fontproperties(myfont)
axes.get_legend().remove()
plt.show()

# %%
#發文者性別比
gender = {"F":0, "M":0}
for content in data:
    gender[content['gender']]+=1
print(gender)
Kind = ['boy','girl']
Data = [gender['F'],gender['M']]
plt.bar(Kind ,Data)
plt.show()
# Out:
# {'F': 54, 'M': 19}

# %%
df = pd.DataFrame(data)
df.columns
d = df[['id', 'title', 'gender', 'topics', 'excerpt', 'createdAt', 'updatedAt', 'commentCount', 'forumName', 'likeCount']]
d.columns = ['ID', '標題', '性別', '標籤', '摘要', '發布時間', '更新時間', '留言數', '分類', '心情數量']
d.tail(50)
# Out:
#            ID                    標題 性別                          標籤  \
# 23  236183562            大家好 我叫做豆皮～  F        [寵物, 狗, 米克斯, 黑犬, 黑狗]
# 24  236187756     #圖#柴 真的是讓人又恨又愛的柴犬  F                 [柴犬, 寵物, 狗]
# 25  236186747               怕打雷的貓貓⛈  F             [貓貓, 貓, 貓咪, 橘貓]
# 26  236182612             請問大家的曼赤肯貓  F            [曼赤肯, 貓, 寵物, 貓咪]
# 27  236179563              極品貓爪陪你上課  F               [貓, 貓掌, 遠距教學]
# 28  236179629                   小笨狗  F                        [寵物]
